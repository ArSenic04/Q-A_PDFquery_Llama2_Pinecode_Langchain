# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("C:\\Desktop_folders\\Coding\\Projects\\Doc_LLM\\2 (2).pdf")
pages = loader.load_and_split()

# %%
pages[0]
# Out:
# Document(page_content='========================================================================================================================\nPANEL/TEST  RESULT  ABNORMAL  UNITS  REFERENCE RANGE\n=================================================================================================================== \nCOMPLETE BLOOD COUNT (CBC)\nWBC  4.1 K/uL  3.5-10.8\nRBC  3.78 L  10 /uL 3.80-5.22\nHGB  11.6 L  g/dL  12.0-16.0\nHCT  36.8 % 35.0-47.0\nMCV  97.4 fL 81.6-98.3\nMCH  30.7 pg 26.0-35.0\nMCHC  31.5 g/dL  29.6-38.0\nRDW  14.0 % 11.5-15.5\nMPV  10.7 fL 9.0-12.6\nPlatelets  253 K/uL  130-400\nAUTOMATED DIFFERENTIAL COUNT\nNeutrophils  47.9 % 40.0-74.0\nNeutrophils#  2.0 10 /uL 1.9-8.0\nLymphocytes  29.6 % 19.0-48.0\nLymphocytes#  1.2 10 /uL 0.9-5.2\nMonocytes  16.0 H  % 0.0-12.0\nMonocytes#  0.7 10 /uL 0.2-1.0\nEosinophils  5.3 % 0.0-7.0\nEosinophils#  0.22 10 /uL 0.00-0.80\nBasophils  0.5 % 0.0-2.0\nBasophils#  0.02 10 /uL 0.00-0.20\nMANUAL DIFFERENTIAL COUNT\nNeutrophils  66 % 40-74\nLymphocytes  22 % 19-48\nMonocytes  10 % 0-12\nEosinophils  2 % 0-7\nBasophils  0 % 0-2\nRBC Morphology  Normal Morphology Seen\nWBC Morphology  Normal Morphology Seen\nPlatelets Morph.  Normal Morphology Seen\nERYTHROCYTE SEDIMENTATION RATE\nSed Rate (ESR)  42 H  mm/hr  0-20\nCHEMISTRY STUDIES\n========================================================================================================================\nPANEL/TEST  RESULT  ABNORMAL  UNITS  REFERENCE RANGE\n===================================================================================================================\nSodium  141 mmol/L  135-146\nPotassium  4.4 mmol/L  3.5-5.5\nChloride  104 mmol/L  98-112\nCO2  25 mmol/L  22-29\nAnion Gap  16.4 mEq/L  0.0-25.0\nGlucose, Fasting  103 H  mg/dL  65-99\nBUN  11 mg/dL  6-23\n6\n3\n3\n3\n3\n3', metadata={'source': 'C:\\Desktop_folders\\Coding\\Projects\\Doc_LLM\\2 (2).pdf', 'page': 0})

# %%
import os
os.environ['OPENAI_API_KEY'] ='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'

# %%
from langchain_community.vectorstores import FAISS

from langchain_openai import OpenAIEmbeddings

faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
docs = faiss_index.similarity_search("How will the community be engaged?", k=2)
for doc in docs:
    print(str(doc.metadata["page"]) + ":", doc.page_content[:300])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 5
#       1 from langchain_community.vectorstores import FAISS
#       3 from langchain_openai import OpenAIEmbeddings
# ----> 5 faiss_index = FAISS.from_documents(pages, OpenAIEmbeddings())
#       6 docs = faiss_index.similarity_search("How will the community be engaged?", k=2)
#       7 for doc in docs:
#
# File c:\Python3.11\Lib\site-packages\langchain_core\vectorstores.py:508, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     506 texts = [d.page_content for d in documents]
#     507 metadatas = [d.metadata for d in documents]
# --> 508 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File c:\Python3.11\Lib\site-packages\langchain_community\vectorstores\faiss.py:913, in FAISS.from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     886 @classmethod
#     887 def from_texts(
#     888     cls,
#    (...)
#     893     **kwargs: Any,
#     894 ) -> FAISS:
#     895     """Construct FAISS wrapper from raw documents.
#     896
#     897     This is a user friendly interface that:
#    (...)
#     911             faiss = FAISS.from_texts(texts, embeddings)
#     912     """
# --> 913     embeddings = embedding.embed_documents(texts)
#     914     return cls.__from(
#     915         texts,
#     916         embeddings,
#    (...)
#     920         **kwargs,
#     921     )
#
# File c:\Python3.11\Lib\site-packages\langchain_openai\embeddings\base.py:482, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     479 # NOTE: to keep things simple, we assume the list may contain texts longer
#     480 #       than the maximum context and use length-safe embedding function.
#     481 engine = cast(str, self.deployment)
# --> 482 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File c:\Python3.11\Lib\site-packages\langchain_openai\embeddings\base.py:325, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     323 batched_embeddings: List[List[float]] = []
#     324 for i in _iter:
# --> 325     response = self.client.create(
#     326         input=tokens[i : i + _chunk_size], **self._invocation_params
#     327     )
#     328     if not isinstance(response, dict):
#     329         response = response.dict()
#
# File c:\Python3.11\Lib\site-packages\openai\resources\embeddings.py:103, in Embeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#      97         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#      98             base64.b64decode(data), dtype="float32"
#      99         ).tolist()
#     101     return obj
# --> 103 return self._post(
#     104     "/embeddings",
#     105     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     106     options=make_request_options(
#     107         extra_headers=extra_headers,
#     108         extra_query=extra_query,
#     109         extra_body=extra_body,
#     110         timeout=timeout,
#     111         post_parser=parser,
#     112     ),
#     113     cast_to=CreateEmbeddingResponse,
#     114 )
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:1112, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1098 def post(
#    1099     self,
#    1100     path: str,
#    (...)
#    1107     stream_cls: type[_StreamT] | None = None,
#    1108 ) -> ResponseT | _StreamT:
#    1109     opts = FinalRequestOptions.construct(
#    1110         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1111     )
# -> 1112     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:859, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     850 def request(
#     851     self,
#     852     cast_to: Type[ResponseT],
#    (...)
#     857     stream_cls: type[_StreamT] | None = None,
#     858 ) -> ResponseT | _StreamT:
# --> 859     return self._request(
#     860         cast_to=cast_to,
#     861         options=options,
#     862         stream=stream,
#     863         stream_cls=stream_cls,
#     864         remaining_retries=remaining_retries,
#     865     )
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:934, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     932 if retries > 0 and self._should_retry(err.response):
#     933     err.response.close()
# --> 934     return self._retry_request(
#     935         options,
#     936         cast_to,
#     937         retries,
#     938         err.response.headers,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941     )
#     943 # If the response is streamed then we need to explicitly read the response
#     944 # to completion before attempting to access the response text.
#     945 if not err.response.is_closed:
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     978 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     979 # different thread if necessary.
#     980 time.sleep(timeout)
# --> 982 return self._request(
#     983     options=options,
#     984     cast_to=cast_to,
#     985     remaining_retries=remaining,
#     986     stream=stream,
#     987     stream_cls=stream_cls,
#     988 )
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:934, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     932 if retries > 0 and self._should_retry(err.response):
#     933     err.response.close()
# --> 934     return self._retry_request(
#     935         options,
#     936         cast_to,
#     937         retries,
#     938         err.response.headers,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941     )
#     943 # If the response is streamed then we need to explicitly read the response
#     944 # to completion before attempting to access the response text.
#     945 if not err.response.is_closed:
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     978 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     979 # different thread if necessary.
#     980 time.sleep(timeout)
# --> 982 return self._request(
#     983     options=options,
#     984     cast_to=cast_to,
#     985     remaining_retries=remaining,
#     986     stream=stream,
#     987     stream_cls=stream_cls,
#     988 )
#
# File c:\Python3.11\Lib\site-packages\openai\_base_client.py:949, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946         err.response.read()
#     948     log.debug("Re-raising status error")
# --> 949     raise self._make_status_error_from_response(err.response) from None
#     951 return self._process_response(
#     952     cast_to=cast_to,
#     953     options=options,
#    (...)
#     956     stream_cls=stream_cls,
#     957 )
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
